# %%
# %pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp39-cp39-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\516-08\anaconda3\envs\torch_book\lib\site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\516-08\anaconda3\envs\torch_book\lib\site-packages (from gensim) (1.13.1)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart_open>=1.8.1->gensim)
#   Downloading wrapt-2.0.1-cp39-cp39-win_amd64.whl.metadata (9.2 kB)
# Downloading gensim-4.4.0-cp39-cp39-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    - -------------------------------------- 1.0/24.4 MB 6.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.9/24.4 MB 8.0 MB/s eta 0:00:03
#    -------- ------------------------------- 5.2/24.4 MB 9.7 MB/s eta 0:00:02
#    -------------- ------------------------- 8.7/24.4 MB 11.4 MB/s eta 0:00:02
#    -------------------- ------------------- 12.6/24.4 MB 12.9 MB/s eta 0:00:01
#    -------------------------- ------------- 16.0/24.4 MB 13.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 17.8/24.4 MB 13.1 MB/s eta 0:00:01
#    --------------------------------- ------ 20.4/24.4 MB 13.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.8/24.4 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.4 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 11.9 MB/s  0:00:02
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading wrapt-2.0.1-cp39-cp39-win_amd64.whl (60 kB)
# Installing collected packages: wrapt, smart_open, gensim
#
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    ---------------------------------------- 3/3 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.5.0 wrapt-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from sklearn.decomposition import PCA
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

glove_file = datapath(r'C:\deep\chap10\data\glove.6B.100d.txt')
word2vec_glove_file = get_tmpfile("glove.6B.100d.word2vec.txt")
glove2word2vec(glove_file, word2vec_glove_file)
# Out:
# C:\Users\516-08\AppData\Local\Temp\ipykernel_16080\3064111312.py:12: DeprecationWarning: Call to deprecated `glove2word2vec` (KeyedVectors.load_word2vec_format(.., binary=False, no_header=True) loads GLoVE text vectors.).
#   glove2word2vec(glove_file, word2vec_glove_file)
# (400000, 100)

# %%
model = KeyedVectors.load_word2vec_format(word2vec_glove_file)
model.most_similar('bill')
# Out:
# [('legislation', 0.8072139620780945),
#  ('proposal', 0.730686366558075),
#  ('senate', 0.7142541408538818),
#  ('bills', 0.704440176486969),
#  ('measure', 0.6958035230636597),
#  ('passed', 0.690624475479126),
#  ('amendment', 0.6846879720687866),
#  ('provision', 0.6845567226409912),
#  ('plan', 0.6816462874412537),
#  ('clinton', 0.6663140058517456)]

# %%
model.most_similar('cherry')
# Out:
# [('peach', 0.688809871673584),
#  ('mango', 0.683819055557251),
#  ('plum', 0.6684104204177856),
#  ('berry', 0.6590359210968018),
#  ('grove', 0.658155083656311),
#  ('blossom', 0.6503506302833557),
#  ('raspberry', 0.6477391719818115),
#  ('strawberry', 0.6442098021507263),
#  ('pine', 0.6390928626060486),
#  ('almond', 0.6379212737083435)]

# %%
model.most_similar(negative=['cherry'])
# Out:
# [('kazushige', 0.48343509435653687),
#  ('askerov', 0.4778185784816742),
#  ('lakpa', 0.46915265917778015),
#  ('ex-gay', 0.4571332633495331),
#  ('tadayoshi', 0.4522107243537903),
#  ('turani', 0.44810065627098083),
#  ('saglam', 0.4469599425792694),
#  ('aijun', 0.4435270130634308),
#  ('adjustors', 0.44235292077064514),
#  ('nyum', 0.4423118233680725)]

# %%
result = model.most_similar(positive=['woman', 'king'], negative=['man'])
print("{}: {:.4f}".format(*result[0]))
# Out:
# queen: 0.7699

# %%
def analogy(x1, x2, y1):
    result = model.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]
analogy('australia', 'beer', 'france')
# Out:
# 'champagne'

# %%
analogy('tall', 'tallest', 'long')
# Out:
# 'longest'

# %%
print(model.doesnt_match("breakfast cereal dinner lunch".split()))
# Out:
# cereal
